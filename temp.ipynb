# %%
import sentencepiece as sp
import random

# %%
tokenizer  = sp.SentencePieceProcessor()
tokenizer.Load('D:/Workspace/PYTHON/NLP/Project2/tokenizer/unigram/unigram_tokenizer.model')
tokenizer
# Out:
# <sentencepiece.SentencePieceProcessor; proxy of <Swig Object of type 'sentencepiece::SentencePieceProcessor *' at 0x000001F243EABE70> >

# %%
vocab_size = tokenizer.get_piece_size()
print("Vocabulary size:", vocab_size)

# ✅ Print all vocabulary tokens
for i in range(vocab_size):
    print(i, tokenizer.id_to_piece(i))
# Out:
# Vocabulary size: 256
# 0 <pad>
# 1 <unk>
# 2 <s>
# 3 </s>
# 4 <mask>
# 5 ی
# 6 ا
# 7 ر
# 8 و
# 9 ہ
# 10 ل
# 11 م
# 12 ت
# 13 ک
# 14 ے
# 15 ن
# 16 د
# 17 ▁ا
# 18 ▁ہے
# 19 س
# 20 ▁م
# 21 ▁
# 22 ▁کی
# 23 ▁کے
# 24 ▁میں
# 25 ب
# 26 ▁س
# 27 ▁ب
# 28 ▁کا
# 29 ٹ
# 30 ان
# 31 ق
# 32 ھ
# 33 ▁ہو
# 34 ▁ت
# 35 ش
# 36 وں
# 37 ز
# 38 ف
# 39 ▁سے
# 40 ▁اس
# 41 ار
# 42 ▁کو
# 43 ج
# 44 ▁ن
# 45 ▁ہیں
# 46 ▁کر
# 47 ▁د
# 48 ▁ک
# 49 ال
# 50 ▁ج
# 51 ▁اور
# 52 ص
# 53 ح
# 54 ▁ان
# 55 ع
# 56 ▁یہ
# 57 ▁و
# 58 یں
# 59 ▁پر
# 60 گ
# 61 ▁ف
# 62 ▁نہیں
# 63 ▁ش
# 64 ▁خ
# 65 ری
# 66 ▁کہ
# 67 ▁ر
# 68 پ
# 69 ط
# 70 ▁ع
# 71 ▁ح
# 72 ام
# 73 ▁تو
# 74 ▁گ
# 75 ▁چ
# 76 تے
# 77 ▁پ
# 78 ▁نے
# 79 ▁ل
# 80 ▁بھی
# 81 ائ
# 82 نا
# 83 ڈ
# 84 ات
# 85 ▁ایک
# 86 نے
# 87 ▁وہ
# 88 ور
# 89 ین
# 90 خ
# 91 چ
# 92 تی
# 93 لی
# 94 ▁ق
# 95 ▁کیا
# 96 ▁ہ
# 97 ▁ہوں
# 98 ظ
# 99 تا
# 100 ▁دی
# 101 اد
# 102 اب
# 103 نگ
# 104 ئے
# 105 ڑ
# 106 ض
# 107 ▁ٹ
# 108 چھ
# 109 اں
# 110 ▁تھا
# 111 ؟
# 112 ▁پاکستان
# 113 ▁جا
# 114 ▁جو
# 115 ائی
# 116 از
# 117 ▁ہم
# 118 ▁ہی
# 119 ▁اب
# 120 ▁نہ
# 121 ئی
# 122 ول
# 123 ▁اپ
# 124 ▁گا
# 125 ▁بن
# 126 ث
# 127 ذ
# 128 ▁پی
# 129 ون
# 130 ▁با
# 131 ▁رو
# 132 ▁لی
# 133 ▁دو
# 134 ▁بہت
# 135 غ
# 136 ▁ز
# 137 ▁کوئی
# 138 ▁ایس
# 139 ▁تھے
# 140 ▁کم
# 141 ▁لیے
# 142 ▁کھ
# 143 ئ
# 144 ▁مع
# 145 ▁تھی
# 146 ▁غ
# 147 ▁گیا
# 148 ▁پہ
# 149 ▁بات
# 150 ▁مس
# 151 ▁اج
# 152 ▁ہمار
# 153 ▁سب
# 154 نڈ
# 155 ▁یا
# 156 ▁لگ
# 157 ▁من
# 158 ▁بڑ
# 159 ▁رکھ
# 160 ▁بھ
# 161 ▁مح
# 162 ▁لوگ
# 163 ▁پا
# 164 ▁اپنے
# 165 ▁جب
# 166 ▁کرتا
# 167 ▁دوسر
# 168 ▁رہا
# 169 ▁میر
# 170 ▁ساتھ
# 171 ▁رہے
# 172 ▁جان
# 173 ▁گر
# 174 ▁کسی
# 175 ▁کرنے
# 176 ▁ہوتا
# 177 ▁وقت
# 178 ائے
# 179 ▁دیکھ
# 180 ▁پھر
# 181 ▁چھ
# 182 ▁اپنی
# 183 ▁لیکن
# 184 ▁کرنا
# 185 ▁سیاس
# 186 ▁ملک
# 187 ▁گئی
# 188 ▁گے
# 189 ▁جائے
# 190 ▁رہی
# 191 ▁پڑ
# 192 ▁گئے
# 193 ▁ضرور
# 194 ▁مجھے
# 195 ▁ٹیم
# 196 ▁حکومت
# 197 ▁دنیا
# 198 ▁چاہیے
# 199 ▁یہاں
# 200 ▁جاتا
# 201 ▁زیاد
# 202 ▁بعد
# 203 ▁اگر
# 204 ▁ادا
# 205 ں
# 206 ▁اسلام
# 207 ▁طرح
# 208 اصل
# 209 ▁قوم
# 210 خلاف
# 211 ▁اللہ
# 212 ▁نظر
# 213 ▁پہلے
# 214 ▁انسان
# 215 ▁سمجھ
# 216 ▁صرف
# 217 ▁جیس
# 218 ▁چاہ
# 219 ▁فلم
# 220 ▁سکتا
# 221 ▁کیلئے
# 222 ▁عمل
# 223 ▁علا
# 224 ▁کرکٹ
# 225 ▁ڈی
# 226 ▁پہنچ
# 227 ▁سوچ
# 228 ▁کبھی
# 229 ▁طرف
# 230 ▁شروع
# 231 ▁صاحب
# 232 ▁والے
# 233 ▁پیدا
# 234 ▁پسند
# 235 ▁بھارت
# 236 ▁طور
# 237 ▁خود
# 238 ▁موجود
# 239 ▁جگہ
# 240 ▁خوش
# 241 ▁تاریخ
# 242 ▁معامل
# 243 ▁شکست
# 244 ▁سامن
# 245 ▁صورت
# 246 ▁استعمال
# 247 ▁وزیر
# 248 ▁ڈال
# 249 ▁زندگی
# 250 ▁مذہب
# 251 ء
# 252 ي
# 253 ژ
# 254 ه
# 255 ى
